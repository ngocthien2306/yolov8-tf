# %%
import tensorflow as tf
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "4"
# Check if GPU is available
print("GPU Available: ", tf.config.list_physical_devices('GPU'))

# More detailed GPU information
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    print(f"Number of GPUs: {len(gpus)}")
    for i, gpu in enumerate(gpus):
        print(f"GPU {i}: {gpu}")
else:
    print("No GPU found")
# Out:
# GPU Available:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:4', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:5', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:6', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:7', device_type='GPU')]
# Number of GPUs: 8
# GPU 0: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# GPU 1: PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')
# GPU 2: PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU')
# GPU 3: PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU')
# GPU 4: PhysicalDevice(name='/physical_device:GPU:4', device_type='GPU')
# GPU 5: PhysicalDevice(name='/physical_device:GPU:5', device_type='GPU')
# GPU 6: PhysicalDevice(name='/physical_device:GPU:6', device_type='GPU')
# GPU 7: PhysicalDevice(name='/physical_device:GPU:7', device_type='GPU')
